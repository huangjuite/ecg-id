# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %%
heart = np.loadtxt('1.txt', delimiter=' ')

# %%
# beat = heart[50:350]
beat = heart
peaks, height = find_peaks(beat, height=0.5)
data = []

for i in range(len(peaks)-1):
    data.append(beat)

# plt.plot(beat)
# plt.plot(peaks, beat[peaks], "x")
# plt.show()
# Out:
# [  195   431   656   875  1088  1303  1529  1773  2018  2240  2444  2648
#   2865  3116  3387  3652  3906  4148  4378  4598  4816  5038  5267  5501
#   5733  5968  6209  6453  6684  6920  7161  7407  7657  7901  8131  8366
#   8605  8847  9096  9345  9599  9601  9848 10089 10316 10545 10768 10983
#  11041 11044 11049 11053 11194 11406 11620 11837 12046 12266 12488 12714
#  12932 13151 13372 13590 13812 14024 14233 14438 14642 14843 15047 15259
#  15496 15731 15958 16177 16391 16599 16805 17012 17221 17429 17632 17832
#  18030 18229 18429 18641 18857 19064 19272 19495 19728 19973 20206 20429
#  20647 20865 21084 21295 21507 21727 21954 22180 22406 22640 22875 23095
#  23318 23547 23773 23993 24215 24441 24674 24905 25126 25349 25579 25820
#  26056 26284 26508 26741 26977 27211 27441 27674 27918 28164 28392 28623
#  28856 29094 29329 29554 29781 30013 30246 30468 30697 30933 31173 31401
#  31629 31858 32092 32315 32537 32762 32997 33231 33452 33680 33917 34164
# ...

# %%
peaks.shape
# Out:
# (414,)
